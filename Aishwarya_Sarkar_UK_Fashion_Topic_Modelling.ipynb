# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import re
import re
import string
import numpy as np
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# Individual cleaning functions
def remove_web_links(text):
    text = re.sub(r'http://www.\w+.org/','', text)
    text = re.sub(r'http://www.([\w\S]+).org/\w+\W\w+','',text)
    text = re.sub(r'https://\w+.\w+/\d+.\d+/\w\d+\W\w+','',text)
    text = re.sub(r'https://\w+.\w+/\d+.\d+/\w\d+\W\w+','',text)
    text = re.sub(r'Figure\s\d:','', text)
    text = re.sub(r'\Wwww.\w+\W\w+\W','',text)
    text = re.sub("@[A-Za-z0-9]+", "", text)
    text = re.sub(r'www.\w+','',text)

    return text

def remove_emojis(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    text = regrex_pattern.sub('', text)

    return text

def remove_spaces(text):
    text = re.sub(r'\n',"",text)

    return text


def remove_stopwords(text):
    stop_words=set(stopwords.words('english'))
    words=word_tokenize(text)
    sentence=[w for w in words if w not in stop_words]
    return " ".join(sentence)

def lemmatize_text(text):
    wordlist=[]
    lemmatizer = WordNetLemmatizer()
    sentences=sent_tokenize(text)
    for sentence in sentences:
        words=word_tokenize(sentence)
        for word in words:
            wordlist.append(lemmatizer.lemmatize(word))
    return ' '.join(wordlist)

def lowercase_text(text):
    return text.lower()


def remove_punctuations(text):
    additional_punctuations = ['’', '…'] # punctuations not in string.punctuation  
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
  
    for punctuation in additional_punctuations:
        text = text.replace(punctuation, '')
    
    return text

def remove_numbers(text):
    if text is not None:
        text = text.replace(r'^\d+\.\s+','')
  
    text = re.sub("[0-9]", '', text)
    return text

# %%
def clean_and_preprocess_data(text, lowercase=True, clean_stopwords=True, clean_punctuations=True, clean_links=True, 
                              clean_emojis=True, clean_spaces=True, clean_numbers=True,  lemmatize=True):
  
    if clean_stopwords == True:
        text = remove_stopwords(text)

    if clean_punctuations == True:
        text = remove_punctuations(text)
  
    if clean_links == True:
        text = remove_web_links(text)
  
    if clean_emojis == True:
        text = remove_emojis(text)
  
    if clean_spaces == True:
        text = remove_spaces(text)
  
    if clean_numbers == True:
        text = remove_numbers(text)
  
    if lemmatize == True:
        text = lemmatize_text(text)
  
    if lowercase == True:
        return text.lower()

    return text

# %%
df2 = pd.read_csv('/content/gdrive/My Drive/Omdena_Normal/full_tag_extracted_results.csv')

# %%
pd.set_option('max_colwidth', None)
df2.head()
# Out:
#    Unnamed: 0                                         id  \
# 0           0  00050113-88d0-5767-b12f-66fac7c3b80d.json
# 1           1  00050113-88d0-5767-b12f-66fac7c3b80d.json
# 2           2  00050113-88d0-5767-b12f-66fac7c3b80d.json
# 3           3  00050113-88d0-5767-b12f-66fac7c3b80d.json
# 4           4  00050113-88d0-5767-b12f-66fac7c3b80d.json
#
#                                                                                            resourceLink  \
# 0  https://www.delmontefoods.com/sites/default/files/pdf/2021-10/2021_DelMonte_SustainabilityReport.pdf
# 1  https://www.delmontefoods.com/sites/default/files/pdf/2021-10/2021_DelMonte_SustainabilityReport.pdf
# 2  https://www.delmontefoods.com/sites/default/files/pdf/2021-10/2021_DelMonte_SustainabilityReport.pdf
# 3  https://www.delmontefoods.com/sites/default/files/pdf/2021-10/2021_DelMonte_SustainabilityReport.pdf
# 4  https://www.delmontefoods.com/sites/default/files/pdf/2021-10/2021_DelMonte_SustainabilityReport.pdf
#
# ...

# %%
#create the dataset for 'UK' and the fashion industry
fashion_data_uk= df2[(df2['industry'] == 'fashion') & (df2['country']=='UK')]
# Out:
# 6988

# %%
len(fashion_data_uk)
# Out:
# 6988

# %%
# %time 
fashion_data_uk['paragraph']=fashion_data_uk['paragraph'].apply(lambda x: clean_and_preprocess_data(x))
fashion_data_uk['paragraph']=fashion_data_uk['paragraph'].replace('\\n', ' ').replace('\n', ' ').replace('\t',' ').replace('\\', ' ').replace('. com', '.com')
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.87 µs

# %%
fashion_data_uk.head()
# Out:
#        Unnamed: 0                                         id  \
# 99649       99649  cc559215-afa8-5109-8cda-dffed55feeac.json
# 99650       99650  cc559215-afa8-5109-8cda-dffed55feeac.json
# 99651       99651  cc559215-afa8-5109-8cda-dffed55feeac.json
# 99652       99652  cc559215-afa8-5109-8cda-dffed55feeac.json
# 99653       99653  cc559215-afa8-5109-8cda-dffed55feeac.json
#
#                                   resourceLink  \
# 99649  http://oro.open.ac.uk/77120/3/77120.pdf
# 99650  http://oro.open.ac.uk/77120/3/77120.pdf
# 99651  http://oro.open.ac.uk/77120/3/77120.pdf
# 99652  http://oro.open.ac.uk/77120/3/77120.pdf
# 99653  http://oro.open.ac.uk/77120/3/77120.pdf
#
#                                                                                            tags  \
# 99649  {'external': ['test'], 'benefit': 'sustainable', 'industry': 'fashion', 'country': 'UK'}
# 99650  {'external': ['test'], 'benefit': 'sustainable', 'industry': 'fashion', 'country': 'UK'}
# ...

# %% [markdown]
# ###BERT topic modellling

# %%
# !pip install bertopic
# Out:
# ...
#      |████████████████████████████████| 57 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 86 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 55.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 79 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 51.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 62.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 46.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 72.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 62.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 52.6 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330795 sha256=8984f16b39b3b7f321dfd3634b2b65c63655a90d333160ddd2ad112634dbe2e2
# ...

# %%
fashion_data_uk['paragraph'].values
# Out:
# array(['black sandy williams dilys rocamora agnes burcikova mila lyon fergus werner andrea vickers ian elf patrick eckert claudia crommentuijnmarsh philippa fostering sustainable practices the case micro small designer fashion enterprise in sustainable innovation mar farnborough',
#        'copyright moral rights article site retained individual author andor copyright owner for information open research online data policy reuse material please consult policy fostering sustainable practices the case micro small professor fashion textile design technology centre sustainable fashion university arts london london college fashion director centre sustainable fashion professor fashion design sustainability university arts london london college fashion',
# ...

# %%
from bertopic import BERTopic

topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True,top_n_words=5)
topics, probs = topic_model.fit_transform(fashion_data_uk['paragraph'].values)
# Out:
# Batches:   0%|          | 0/219 [00:00<?, ?it/s]
# 2022-03-31 11:58:59,754 - BERTopic - Transformed documents to Embeddings
# 2022-03-31 11:59:39,720 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-31 11:59:44,292 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                          Name
# 0       -1   3081           -1_fashion_clothing_the_sustainable
# 1        0    185           0_csr_financial_discourse_recession
# 2        1    103                   1_journal_vol_management_pp
# 3        2    103               2_supply_chain_supplier_network
# 4        3     89       3_rental_margin_recommerce_subscription
# ..     ...    ...                                           ...
# 117    116     11       116_usbased_recommerce_ukbased_clothing
# 118    117     11      117_respondent_clothes_purchase_clothing
# 119    118     11   118_communication_empirical_retailer_aspect
# 120    119     11         119_clothes_its_something_participant
# 121    120     10  120_greenwashing_green_sustainability_amsler
#
# [122 rows x 3 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('csr', 0.0472600910734117),
#  ('financial', 0.03533361653691373),
#  ('discourse', 0.03122843600407323),
#  ('recession', 0.02443039381281884),
#  ('responsibility', 0.02161092473993931)]

# %%
topic_model.get_topic(4)
# Out:
# [('blockchain', 0.08011292887931974),
#  ('proposition', 0.031084963445215358),
#  ('advertisement', 0.030725032479279154),
#  ('manufacturer', 0.030274149782674495),
#  ('disclosure', 0.02972607359223593)]

# %%
topic_model.get_topic_freq()
# Out:
#      Topic  Count
# 0       -1   3081
# 1        0    185
# 2        1    103
# 3        2    103
# 4        3     89
# ..     ...    ...
# 117    116     11
# 118    117     11
# 119    118     11
# 120    119     11
# 121    120     10
#
# [122 rows x 2 columns]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
